# %%
from urllib.request import urlopen

with urlopen('https://www.wikidata.org/wiki/Q13417213') as webpage:
    content = webpage.read().decode()
    # which strings are anagrams of each other
    # which strings are palindromes

print(content)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Mom - Wikidata</title>
# ...

# %%
https://www.wikidata.org/wiki/Q13417213

# %%
import shutil
import tempfile
import urllib.request


data = urlopen('https://www.wikidata.org/wiki/Q13417213') 
for line in data: 
    print(line)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bfcf98cacc72> in <module>
#       4
#       5
# ----> 6 data = urlopen('https://www.wikidata.org/wiki/Q13417213')
#       7 for line in data:
#       8     print(line)
#
# NameError: name 'urlopen' is not defined
